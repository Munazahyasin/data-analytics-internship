# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-301b8c08-b445-430a-be8e-f17d3fc2370c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-301b8c08-b445-430a-be8e-f17d3fc2370c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("Day10_Flight_Operations_Dataset.csv")

# %%
df = pd.read_csv("Day10_Flight_Operations_Dataset.csv")

# %%
df.head()
# Out:
#   Flight_ID Flight_Date    Airline    Origin Destination     Aircraft  \
# 0    FL0001  2026-03-23   SpiceJet    Mumbai   Bengaluru  Airbus A319
# 1    FL0002  2026-06-07  Akasa Air     Delhi      Mumbai   Boeing 737
# 2    FL0003  2026-05-12  Air India     Kochi       Delhi   Boeing 737
# 3    FL0004  2026-05-30  Akasa Air  Srinagar       Delhi  Airbus A319
# 4    FL0005  2026-02-27  Air India      Pune       Delhi  Airbus A319
#
#       Travel_Class  Passengers  Seat_Capacity  Average_Ticket_Price  \
# 0          Economy         210            180                  6894
# 1          Economy          70            210                  4468
# 2          Economy          67            220                  4713
# 3          Economy         153            220                  3791
# 4  Premium Economy         178            180                  6505
#
#    Delay_Minutes Flight_Status Weather       Booking_Channel  Avg_Baggage_Kg  \
# ...

# %%
df.tail()
# Out:
#     Flight_ID Flight_Date    Airline     Origin Destination     Aircraft  \
# 175    FL0176  2026-04-10     IndiGo  Ahmedabad   Bengaluru  Airbus A320
# 176    FL0177  2026-02-17    Vistara    Chennai      Mumbai  Airbus A320
# 177    FL0178  2026-04-30     IndiGo      Delhi      Mumbai  Airbus A319
# 178    FL0179  2026-05-08    Vistara  Bengaluru       Kochi  Airbus A320
# 179    FL0180  2026-01-22  Akasa Air      Delhi      Mumbai  Airbus A321
#
#     Travel_Class  Passengers  Seat_Capacity  Average_Ticket_Price  \
# 175      Economy          48            189                  4298
# 176     Business         124            180                 17306
# 177      Economy         112            186                  4490
# 178      Economy         134            189                  5413
# 179      Economy         144            210                  3767
#
#      Delay_Minutes Flight_Status Weather       Booking_Channel  \
# ...

# %%
df.sample(5)

# %% [markdown]
# ### Generate statistics

# %%
df.describe()

# %%
df.isnull().sum()

# %%
(df.isnull().sum() / len(df)) * 100

# %%
df.duplicated().sum()

# %% [markdown]
# ### Individual Columns

# %%
df["Origin"].unique()
# Out:
# array(['Mumbai', 'Delhi', 'Kochi', 'Srinagar', 'Pune', 'Ahmedabad',
#        'Lucknow', 'Jaipur', 'Bengaluru', 'Chennai', 'Hyderabad'],
#       dtype=object)

# %%
df["Airline"].unique()
# Out:
# array(['SpiceJet', 'Akasa Air', 'Air India', 'Air India Express',
#        'Vistara', 'IndiGo'], dtype=object)

# %% [markdown]
# Data Selection

# %%
df["Airline"]

# %%
df[["Origin", "Destination"]]
# Out:
#         Origin Destination
# 0       Mumbai   Bengaluru
# 1        Delhi      Mumbai
# 2        Kochi       Delhi
# 3     Srinagar       Delhi
# 4         Pune       Delhi
# ..         ...         ...
# 175  Ahmedabad   Bengaluru
# 176    Chennai      Mumbai
# 177      Delhi      Mumbai
# 178  Bengaluru       Kochi
# 179      Delhi      Mumbai
#
# [180 rows x 2 columns]

# %% [markdown]
# Flitering

# %%
df[df["Flight_Status"] == "Delayed"]

# %%
df[(df["Meal_Preference"] == "No Meal") & (df["Flight_Status"] == "Delayed")]
# Out:
#     Flight_ID Flight_Date            Airline     Origin Destination  \
# 0      FL0001  2026-03-23           SpiceJet     Mumbai   Bengaluru
# 3      FL0004  2026-05-30          Akasa Air   Srinagar       Delhi
# 4      FL0005  2026-02-27          Air India       Pune       Delhi
# 32     FL0033  2026-04-27          Akasa Air  Ahmedabad   Bengaluru
# 42     FL0043  2026-06-19            Vistara      Delhi     Chennai
# 43     FL0044  2026-04-20  Air India Express  Bengaluru   Hyderabad
# 53     FL0054  2026-04-11           SpiceJet     Mumbai   Bengaluru
# 58     FL0059  2026-01-10  Air India Express      Delhi    Srinagar
# 80     FL0081  2026-04-03           SpiceJet      Delhi      Mumbai
# 100    FL0101  2026-05-24             IndiGo     Jaipur      Mumbai
# 131    FL0132  2026-02-04          Air India  Hyderabad     Kolkata
# 144    FL0145  2026-01-20          Akasa Air  Bengaluru   Hyderabad
# 159    FL0160  2026-06-23            Vistara    Lucknow       Delhi
# ...

# %% [markdown]
# Sorting

# %%
df.sort_values("Delay_Minutes", ascending=False)

# %% [markdown]
# ### Grouping

# %%
df.groupby("Airline")["Passengers"].sum()
# Out:
# Airline
# Air India            3074
# Air India Express    3027
# Akasa Air            3427
# IndiGo               4158
# SpiceJet             3929
# Vistara              4484
# Name: Passengers, dtype: int64

# %%
df.groupby("Airline")["Passengers"].mean()
# Out:
# Airline
# Air India            128.083333
# Air India Express    126.125000
# Akasa Air            110.548387
# IndiGo               129.937500
# SpiceJet             122.781250
# Vistara              121.189189
# Name: Passengers, dtype: float64

# %% [markdown]
# ### Aggregation

# %%
df.groupby("Airline")["Passengers"].agg(["sum", "mean", "min", "max", "count"])
# Out:
#                     sum        mean  min  max  count
# Airline
# Air India          3074  128.083333   45  201     24
# Air India Express  3027  126.125000   57  209     24
# Akasa Air          3427  110.548387   50  202     31
# IndiGo             4158  129.937500   48  198     32
# SpiceJet           3929  122.781250   49  210     32
# Vistara            4484  121.189189   45  209     37

# %%
df.groupby(["Airline", "Flight_Status"]).size()
# Out:
# Airline            Flight_Status
# Air India          Cancelled         1
#                    Delayed           9
#                    On Time          14
# Air India Express  Delayed           6
#                    On Time          18
# Akasa Air          Cancelled         1
#                    Delayed           8
#                    On Time          22
# IndiGo             Delayed          11
#                    On Time          21
# SpiceJet           Cancelled         3
#                    Delayed          12
#                    On Time          17
# Vistara            Cancelled         2
#                    Delayed          13
#                    On Time          22
# dtype: int64

# %% [markdown]
# ### Data Transformation

# %%
df["Flight Duration Hours"] = df["Delay_Minutes"].apply(lambda x: x / 60)

# %% [markdown]
# MeaningFul questions

# %%
#Which airline has the highest number of flights?
df["Airline"].value_counts()
# Out:
# Airline
# Vistara              37
# SpiceJet             32
# IndiGo               32
# Akasa Air            31
# Air India Express    24
# Air India            24
# Name: count, dtype: int64

# %%
#What is the average flight delay time for each airline?
df.groupby("Airline")["Delay_Minutes"].mean()
# Out:
# Airline
# Air India            21.260870
# Air India Express    11.291667
# Akasa Air            14.400000
# IndiGo               25.031250
# SpiceJet             24.137931
# Vistara              18.628571
# Name: Delay_Minutes, dtype: float64

# %%
#How many flights are delayed?
df["Flight_Status"].value_counts()
# Out:
# Flight_Status
# On Time      114
# Delayed       59
# Cancelled      7
# Name: count, dtype: int64
